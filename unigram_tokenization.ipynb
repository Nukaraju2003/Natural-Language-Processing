# %% [markdown]
# <a href="https://colab.research.google.com/github/Nukaraju2003/Natural-Language-Processing/blob/main/unigram_tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
corpus = [
    "This is the Hugging Face Course.",
    "This chapter is about tokenization.",
    "This section shows several tokenizer algorithms.",
    "Hopefully, you will be able to understand how they are trained and generate tokens.",
]

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.3 MB 9.0 MB/s
# ...
#      |████████████████████████████████| 163 kB 53.2 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 45.2 MB/s
# ...

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("xlnet-base-cased")
# Out:
# Downloading:   0%|          | 0.00/760 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.38M [00:00<?, ?B/s]

# %%
from collections import defaultdict

word_freqs = defaultdict(int)
for text in corpus:
    words_with_offsets = tokenizer.backend_tokenizer.pre_tokenizer.pre_tokenize_str(text)
    new_words = [word for word, offset in words_with_offsets]
    for word in new_words:
        word_freqs[word] += 1

word_freqs
# Out:
# defaultdict(int,
#             {'▁This': 3,
#              '▁is': 2,
#              '▁the': 1,
#              '▁Hugging': 1,
#              '▁Face': 1,
#              '▁Course.': 1,
#              '▁chapter': 1,
#              '▁about': 1,
#              '▁tokenization.': 1,
#              '▁section': 1,
#              '▁shows': 1,
#              '▁several': 1,
#              '▁tokenizer': 1,
#              '▁algorithms.': 1,
#              '▁Hopefully,': 1,
#              '▁you': 1,
#              '▁will': 1,
#              '▁be': 1,
#              '▁able': 1,
#              '▁to': 1,
#              '▁understand': 1,
#              '▁how': 1,
#              '▁they': 1,
#              '▁are': 1,
#              '▁trained': 1,
#              '▁and': 1,
#              '▁generate': 1,
#              '▁tokens.': 1})

# %%
char_freqs = defaultdict(int)
subwords_freqs = defaultdict(int)
for word, freq in word_freqs.items():
    for i in range(len(word)):
        char_freqs[word[i]] += freq
        # Loop through the subwords of length at least 2
        for j in range(i + 2, len(word) + 1):
            subwords_freqs[word[i:j]] += freq

# Sort subwords by frequency
sorted_subwords = sorted(subwords_freqs.items(), key=lambda x: x[1], reverse=True)
sorted_subwords[:10]
# Out:
# [('▁t', 7),
#  ('is', 5),
#  ('er', 5),
#  ('▁a', 5),
#  ('▁to', 4),
#  ('to', 4),
#  ('en', 4),
#  ('▁T', 3),
#  ('▁Th', 3),
#  ('▁Thi', 3)]
